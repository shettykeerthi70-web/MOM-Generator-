# %% [markdown]
# ## extracting text from different file sources.
#
# * image
# * PDF
# * DOCX

# %% [markdown]
# ### extracting text from images
# OCR (Optical Character Recognition)

# %%
 pip install pytesseract opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Keerthi Shetty\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# ...

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\Keerthi Shetty\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy<2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the file specified.

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt

# %%
# lets load and process the image 
image=cv2.imread('handwritten.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB) # to convert BGR to RGB 
image_grey=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # to convert BGR to GRey 
_, image_bw=cv2.threshold(image_grey,120,255,cv2.THRESH_BINARY) # to convert grey to balck and white

# %%
plt.imshow(image_bw)

# %%
#cv2.imshow('Grey Image',image_bw)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
pytesseract.pytesseract.tesseract_cmd=r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
print(pytesseract.image_to_string(image_bw))
# Out:
# af Blow Ef. -&
# ‘Tt 7 [aad Ge =
#
# fea ee
# Peay = Coa bP Fly et
# faba ,
# { 4, Mecerddt be peel? & Hing,
#
# Ckeees C how)
# |
#
# ! i
#
# ‘ ia NA
#
# Bucy Pyar crs Vavione Firus Konan: Bors
#
# fete cra den had BENG | + fies
#
# a en ee
# oe poe
# J , ‘ 4
# pens redlrotin Pebe by Boars By Brarby Biss
# er eT geatae Agathe ESN
# jeleciosy . ‘yy
# prcthoo? . purtiod .
# y fevvur'l
# ny ahewe fo RE Bras
# taeeel cute t oS gal :
#
# Qrore a .
# / Se if yf N
# co Zoe
#
# ad 346!
#
# ni alga eth perprrmcaier gn 5 5 sl
# veda Vaz ceeet Byvr
# 3 oal:
#
# beanu Bron ceannel be ter .
# bit tan & Gerdiuced
#
# Pampom EARRS -
# a Rand one gS vors om
#
# caret

# %% [markdown]
# note:
#
# * tesseract is working fine when we have a clear image with typed character , but as we are giving an image of handwritten notes
# the text that it is extracting is not good enough.
#
# * lets try another approach and use LLM model as OCR , we will the result and see.

# %%
import google.generativeai as genai
import cv2
import os
from PIL import Image

# %%
key=os.getenv("GOOGLE_API+_KEY")
genai.configure(api_key=key)

# %%
model=genai.GenerativeModel('gemini-2.5-flash-lite')

# %%
prompt='''You need to perform OCR on the given image and extract th etext from it. 
give only the text as output , do not give any other explaination or description.'''

# %%
# lets load and process the image 
image=cv2.imread('handwritten.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB) 
image_grey=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
_, image_bw=cv2.threshold(image_grey,150,255,cv2.THRESH_BINARY)

# %%
# the image that cv2 is in numpy array format , we need TO CONVERT IT TO IMAGE OBJECT 
final_image=Image.fromarray(image_bw)

# %%
final_image
# Out:
# <PIL.Image.Image image mode=L size=960x1280>

# %%
response=model.generate_content([prompt,final_image])
output_text=response.text
print(output_text)
# Out:
# Bias is inability of the model to predict things
# Why does biased come into existence?
# RIGHTS
# ERRORS C Sources)
# Bias Errors
# Variance Errors
# Random Errors.
# Let's understand sources of Bias.
# Bias in
# collecting
# data
# Bias By
# feature
# selection
# methods
# Bias By
# Feature
# Engineering
# method
# Bias by
# Algorithms
# Bias
# Introduced
# by AS.
# We strive to reduce Bias Error.
# Variance 1
# Errors
# Model
# Variation in the performance of
# model. Variance Error.
# Variance Error cannot be zero.
# But can be reduced.
# RANDOM ERRORS
# → Random Errors
# cannot

# %%
import numpy as np

# %% [markdown]
# Note:
#
# OCR Based on LLM model seems to be a better option to extract text even from handwritten notes. it may not be able to extract 100% but still its giving better output than tesseract

# %% [markdown]
# ## Extract text from DOCX (word Document)

# %%
#pip install python-docx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# %%
# lets read the docx file 
file=Document('stats.docx')

# %%
pip install pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
